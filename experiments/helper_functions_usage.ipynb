# %% [markdown]
# ---
# ---
# ---

# %%
import random
import numpy as np
import pandas as pd
import seaborn as sns
import sqlite3
import matplotlib.pyplot as plt

# %%
import os

# Get the current working directory (the directory from which the script is executed)
current_directory = os.getcwd()

# Define the path to the 'src' folder relative to the current directory
src_directory = os.path.join(current_directory, 'src')

# Change the working directory to the root of the project
os.chdir(current_directory)

# Verify the change (optional)
print("Updated Working Directory:", os.getcwd())
# Out:
# Updated Working Directory: C:\Users\user\assign_dir\Prediction_Of_Heart_Failure

# %%
from src.data_preprocessing import preprocess_data
preprocess_data( "data/raw/heart.csv", "data/processed/heart_cleaned_data.csv")

# %% [markdown]
# - **How to use function df_to_csv helper function**

# %%
from src.df_to_csv import save_df_to_csv


data_file = "data/raw/heart.csv"
heart_data = pd.read_csv(data_file)
categorical_features = ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']

data_frame= heart_data[categorical_features]
output_file = "data/processed/categorical_features.csv"


# Save the processed DataFrame to CSV
save_df_to_csv(data_frame, output_file)
# Out:
# DataFrame saved to data/processed/categorical_features.csv.

# %% [markdown]
# - **How to use function df_to_sql helper function**

# %%
from src.df_to_sql import save_to_sqlite

# Define your parameters
db_file = 'data/SQL/Heart_failure_numeric_features.db'
table_name = 'Heart_Failure_numeric_features'
numeric_X = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
df_numeric_X = heart_data[numeric_X]

# Call the function to save the DataFrame
save_to_sqlite(db_file, table_name, df_numeric_X)
# Out:
# The data has been successfully imported into the 'Heart_Failure_numeric_features' table.

# %% [markdown]
# - **How to use function plot_categorical_analysis helper function**

# %%
import pandas as pd
from src.plot_categorical_analysis import plot_categorical_analysis

# Load the dataset
data_file = "data/raw/heart.csv"
heart_data = pd.read_csv(data_file)

# Define categorical features and target
categorical_features = ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope']
target = 'HeartDisease'

# Output file for the visualizations
output_file = "../reports/visualizations/heart_disease_categorical_features_analysis.png"

# Generate and save the plots
plot_categorical_analysis(heart_data, categorical_features, target, output_file, palette="Set2")
# Out:
# Categorical analysis plots saved to ../reports/visualizations/heart_disease_categorical_features_analysis.png.

# %% [markdown]
# - **How to use function plot_numeric_features_analysis helper function**

# %%
from src.plot_numeric_features_analysis import plot_numeric_analysis

# Load the dataset
data_file = "data/raw/heart.csv"
heart_data = pd.read_csv(data_file)

# Define numeric features and target
numeric_features = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']  # Replace with your numeric features
target = 'HeartDisease'

# Output file for the visualizations
output_file = "reports/visualizations/heart_disease_numeric_features_analysis_1.png"

# Generate and save the plots
plot_numeric_analysis(heart_data, numeric_features, target, output_file, palette="colorblind", figsize=(25, 8))
# Out:
# Numeric analysis plots saved to reports/visualizations/heart_disease_numeric_features_analysis_1.png.
